# %%
import os
import natsort 
import easyocr
import pandas as pd

# %%
file_path = '/Users/jiseungmin/Desktop/AIContest/open/train'
file_list = os.listdir(file_path)
file_names = natsort.natsorted(file_list)
file_names[:10]
# Out:
# ['train_00001.png',
#  'train_00002.png',
#  'train_00003.png',
#  'train_00004.png',
#  'train_00005.png',
#  'train_00006.png',
#  'train_00007.png',
#  'train_00008.png',
#  'train_00009.png',
#  'train_00010.png']

# %%
df1 = pd.read_csv('open/test.csv')
df2 = pd.read_csv("open/train.csv")
df2.head()
# Out:
#                   img_path    text
# 0  ./train/train_00001.png   골목미용실
# 1  ./train/train_00002.png   한성부동산
# 2  ./train/train_00003.png    홍라운지
# 3  ./train/train_00004.png  모단걸응접실
# 4  ./train/train_00005.png    씨앗양식

# %%
# image 전처리
for i in file_list:
    src = os.path.join(file_path, name)
    dst = os.path.join("/Users/jiseungmin/Desktop/AIContest/open/train", "train{}"+".jpg".format(i))
    i+=1
    os.rename(src, dst)

# %%
result=[0]*12158
for i in range(0,12169):
  reader = easyocr.Reader(['ko'], model_storage_directory='/Users/jiseungmin/Desktop/AIContest/custom_example',
  user_network_directory='/Users/jiseungmin/Desktop/AIContest/custom_example',
  recog_network='custom')
  result[i] = reader.readtext("open/train/train{}.png".format(i))
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...

# %%
result[7]
# Out:
# [([[0, 0], [215, 0], [215, 150], [0, 150]], 'tna ', 0.01578926295042038)]
